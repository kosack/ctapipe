# %% [markdown]
# # Using the ctapipe Provenance service
#
# The provenance functionality is used automatically when you use most of ctapipe functionality (particularly `ctapipe.core.Tool` and functions in `ctapipe.io` and `ctapipe.utils`), so normally you don't have to work with it directly. It tracks both input and output files, as well as details of the machine and software environment on which a Tool executed.
#
# Here we show some very low-level functions of this system:

# %%
from ctapipe.core import Provenance
from pprint import pprint

# %% [markdown]
# ## Activities
#
# The basis of Provenance is an *activity*, which is generally an executable or step in a script. Activities can be nested (e.g. with sub-activities), as shown below, but normally this is not required:

# %%
p = Provenance()  # note this is a singleton, so only ever one global provenence object
p.clear()
p.start_activity()
p.add_input_file("test.txt")

p.start_activity("sub")
p.add_input_file("subinput.txt")
p.add_input_file("anothersubinput.txt")
p.add_output_file("suboutput.txt")
p.finish_activity("sub")

p.start_activity("sub2")
p.add_input_file("sub2input.txt")
p.finish_activity("sub2")

p.finish_activity()

# %%
p.finished_activity_names
# Out:
# ['sub', 'sub2', '/opt/hostedtoolcache/Python/3.8.13/x64/bin/python']

# %% [markdown]
# Activities have associated input and output *entities*  (files or other objects)

# %%
[ (x['activity_name'], x['input']) for x in p.provenance]
# Out:
# [('sub',
#   [{'url': '/home/runner/work/ctapipe/ctapipe/docs/examples/subinput.txt',
#     'role': None},
#    {'url': '/home/runner/work/ctapipe/ctapipe/docs/examples/anothersubinput.txt',
#     'role': None}]),
#  ('sub2',
#   [{'url': '/home/runner/work/ctapipe/ctapipe/docs/examples/sub2input.txt',
#     'role': None}]),
#  ('/opt/hostedtoolcache/Python/3.8.13/x64/bin/python',
#   [{'url': '/home/runner/work/ctapipe/ctapipe/docs/examples/test.txt',
#     'role': None}])]

# %% [markdown]
# Activities track when they were started and finished:

# %%
[ (x['activity_name'],x['duration_min']) for x in p.provenance]
# Out:
# [('sub', 0.00013333333333420683),
#  ('sub2', 0.00016666666654785445),
#  ('/opt/hostedtoolcache/Python/3.8.13/x64/bin/python', 0.002166666666640893)]

# %% [markdown]
# ## Full provenance
#
# The provence object is a list of activitites, and for each lots of details are collected:

# %%
p.provenance[0]
# Out:
# {'activity_name': 'sub',
#  'activity_uuid': '26cf18b1-81db-4820-b6ce-d7d02806ba5d',
#  'start': {'time_utc': '2022-08-01T10:06:04.055'},
#  'stop': {'time_utc': '2022-08-01T10:06:04.063'},
#  'system': {'ctapipe_version': '0.7.1.dev1230+g2c82d492',
#   'ctapipe_resources_version': 'not installed',
#   'eventio_version': '1.9.1',
#   'ctapipe_svc_path': None,
#   'executable': '/opt/hostedtoolcache/Python/3.8.13/x64/bin/python',
#   'platform': {'architecture_bits': '64bit',
#    'architecture_linkage': 'ELF',
#    'machine': 'x86_64',
#    'processor': 'x86_64',
#    'node': 'fv-az180-230',
#    'version': '#17~20.04.1-Ubuntu SMP Thu Jun 23 20:01:51 UTC 2022',
#    'system': 'Linux',
#    'release': '5.15.0-1014-azure',
#    'libcver': ('glibc', '2.31'),
#    'n_cpus': 2,
#    'boot_time': '2022-08-01T09:59:44.000'},
#   'python': {'version_string': '3.8.13 (default, Jul 22 2022, 10:44:13) \n[GCC 9.4.0]',
#    'version': ('3', '8', '13'),
#    'compiler': 'GCC 9.4.0',
#    'implementation': 'CPython',
#    'packages': [{'name': 'Babel',
#      'version': '2.10.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'Jinja2',
#      'version': '3.0.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'MarkupSafe',
#      'version': '2.1.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'Pillow',
#      'version': '9.2.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'PyYAML',
#      'version': '6.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'Pygments',
#      'version': '2.12.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'QtPy',
#      'version': '2.1.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'Send2Trash',
#      'version': '1.8.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'Sphinx',
#      'version': '3.5.4',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'alabaster',
#      'version': '0.7.12',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'argon2-cffi',
#      'version': '21.3.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'argon2-cffi-bindings',
#      'version': '21.2.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'astropy',
#      'version': '5.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'asttokens',
#      'version': '2.0.5',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'attrs',
#      'version': '22.1.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'backcall',
#      'version': '0.2.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'beautifulsoup4',
#      'version': '4.11.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'bleach',
#      'version': '5.0.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'bokeh',
#      'version': '2.4.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'certifi',
#      'version': '2022.6.15',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'cffi',
#      'version': '1.15.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'charset-normalizer',
#      'version': '2.1.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'corsikaio',
#      'version': '0.2.5',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'ctapipe',
#      'version': '0.7.1.dev1230+g2c82d492',
#      'path': '/home/runner/work/ctapipe/ctapipe'},
#     {'name': 'cycler',
#      'version': '0.11.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'debugpy',
#      'version': '1.6.2',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'decorator',
#      'version': '5.1.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'defusedxml',
#      'version': '0.7.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'docutils',
#      'version': '0.16',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'entrypoints',
#      'version': '0.4',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'eventio',
#      'version': '1.9.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'executing',
#      'version': '0.9.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'fastjsonschema',
#      'version': '2.16.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'fonttools',
#      'version': '4.34.4',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'graphviz',
#      'version': '0.20.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'h5py',
#      'version': '3.7.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'idna',
#      'version': '3.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'imagesize',
#      'version': '1.4.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'iminuit',
#      'version': '2.15.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'importlib-metadata',
#      'version': '4.12.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'importlib-resources',
#      'version': '5.9.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'ipykernel',
#      'version': '6.15.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'ipython',
#      'version': '8.4.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'ipython-genutils',
#      'version': '0.2.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'ipywidgets',
#      'version': '7.7.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'jedi',
#      'version': '0.18.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'joblib',
#      'version': '1.1.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'jsonschema',
#      'version': '4.9.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'jupyter',
#      'version': '1.0.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'jupyter-client',
#      'version': '7.3.4',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'jupyter-console',
#      'version': '6.4.4',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'jupyter-core',
#      'version': '4.11.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'jupyterlab-pygments',
#      'version': '0.2.2',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'jupyterlab-widgets',
#      'version': '1.1.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'kiwisolver',
#      'version': '1.4.4',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'llvmlite',
#      'version': '0.39.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'matplotlib',
#      'version': '3.5.2',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'matplotlib-inline',
#      'version': '0.1.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'mistune',
#      'version': '0.8.4',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'nbclient',
#      'version': '0.6.6',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'nbconvert',
#      'version': '6.5.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'nbformat',
#      'version': '5.4.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'nbsphinx',
#      'version': '0.8.9',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'nest-asyncio',
#      'version': '1.5.5',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'notebook',
#      'version': '6.4.12',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'numba',
#      'version': '0.56.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'numexpr',
#      'version': '2.8.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'numpy',
#      'version': '1.22.4',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'numpydoc',
#      'version': '1.4.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'packaging',
#      'version': '21.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pandas',
#      'version': '1.4.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pandocfilters',
#      'version': '1.5.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'parso',
#      'version': '0.8.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pexpect',
#      'version': '4.8.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pickleshare',
#      'version': '0.7.5',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pip',
#      'version': '22.2.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pkgutil-resolve-name',
#      'version': '1.3.10',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'prometheus-client',
#      'version': '0.14.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'prompt-toolkit',
#      'version': '3.0.30',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'psutil',
#      'version': '5.9.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'ptyprocess',
#      'version': '0.7.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pure-eval',
#      'version': '0.2.2',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pycparser',
#      'version': '2.21',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pyerfa',
#      'version': '2.0.0.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pyparsing',
#      'version': '3.0.9',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pyrsistent',
#      'version': '0.18.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'python-dateutil',
#      'version': '2.8.2',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pytz',
#      'version': '2022.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'pyzmq',
#      'version': '23.2.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'qtconsole',
#      'version': '5.3.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'requests',
#      'version': '2.28.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'scikit-learn',
#      'version': '1.1.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'scipy',
#      'version': '1.9.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'setuptools',
#      'version': '63.3.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'setuptools-scm',
#      'version': '7.0.5',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'six',
#      'version': '1.16.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'snowballstemmer',
#      'version': '2.2.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'soupsieve',
#      'version': '2.3.2.post1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'sphinx-automodapi',
#      'version': '0.14.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'sphinx-rtd-theme',
#      'version': '1.0.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-applehelp',
#      'version': '1.0.2',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-devhelp',
#      'version': '1.0.2',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-htmlhelp',
#      'version': '2.0.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-jsmath',
#      'version': '1.0.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-qthelp',
#      'version': '1.0.3',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'sphinxcontrib-serializinghtml',
#      'version': '1.1.5',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'stack-data',
#      'version': '0.3.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'tables',
#      'version': '3.7.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'terminado',
#      'version': '0.15.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'threadpoolctl',
#      'version': '3.1.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'tinycss2',
#      'version': '1.1.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'tomli',
#      'version': '2.0.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'tornado',
#      'version': '6.2',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'tqdm',
#      'version': '4.64.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'traitlets',
#      'version': '5.3.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'typing-extensions',
#      'version': '4.3.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'urllib3',
#      'version': '1.26.11',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'wcwidth',
#      'version': '0.2.5',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'webencodings',
#      'version': '0.5.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'wheel',
#      'version': '0.37.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'widgetsnbextension',
#      'version': '3.6.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'zipp',
#      'version': '3.8.1',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'},
#     {'name': 'zstandard',
#      'version': '0.18.0',
#      'path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages'}]},
#   'environment': {'CONDA_DEFAULT_ENV': None,
#    'CONDA_PREFIX': None,
#    'CONDA_PYTHON_EXE': None,
#    'CONDA_EXE': None,
#    'CONDA_PROMPT_MODIFIER': None,
#    'CONDA_SHLVL': None,
#    'PATH': '/opt/hostedtoolcache/Python/3.8.13/x64/bin:/opt/hostedtoolcache/Python/3.8.13/x64:/home/linuxbrew/.linuxbrew/bin:/home/linuxbrew/.linuxbrew/sbin:/home/runner/.local/bin:/opt/pipx_bin:/home/runner/.cargo/bin:/home/runner/.config/composer/vendor/bin:/usr/local/.ghcup/bin:/home/runner/.dotnet/tools:/snap/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin',
#    'LD_LIBRARY_PATH': '/opt/hostedtoolcache/Python/3.8.13/x64/lib',
#    'DYLD_LIBRARY_PATH': None,
#    'USER': 'runner',
#    'HOME': '/home/runner',
#    'SHELL': None},
#   'arguments': ['/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages/ipykernel_launcher.py',
#    '-f',
#    '/tmp/tmpcg_ktt14.json',
#    '--HistoryManager.hist_file=:memory:'],
#   'start_time_utc': '2022-08-01T10:06:04.063'},
#  'input': [{'url': '/home/runner/work/ctapipe/ctapipe/docs/examples/subinput.txt',
#    'role': None},
#   {'url': '/home/runner/work/ctapipe/ctapipe/docs/examples/anothersubinput.txt',
#    'role': None}],
#  'output': [{'url': '/home/runner/work/ctapipe/ctapipe/docs/examples/suboutput.txt',
#    'role': None}],
#  'status': 'sub',
#  'duration_min': 0.00013333333333420683}

# %% [markdown]
# This can be better represented in JSON:

# %%
print(p.as_json(indent=2))
# Out:
# [
#   {
#     "activity_name": "sub",
#     "activity_uuid": "26cf18b1-81db-4820-b6ce-d7d02806ba5d",
#     "start": {
#       "time_utc": "2022-08-01T10:06:04.055"
#     },
#     "stop": {
#       "time_utc": "2022-08-01T10:06:04.063"
#     },
#     "system": {
#       "ctapipe_version": "0.7.1.dev1230+g2c82d492",
#       "ctapipe_resources_version": "not installed",
#       "eventio_version": "1.9.1",
#       "ctapipe_svc_path": null,
#       "executable": "/opt/hostedtoolcache/Python/3.8.13/x64/bin/python",
#       "platform": {
#         "architecture_bits": "64bit",
#         "architecture_linkage": "ELF",
#         "machine": "x86_64",
#         "processor": "x86_64",
#         "node": "fv-az180-230",
#         "version": "#17~20.04.1-Ubuntu SMP Thu Jun 23 20:01:51 UTC 2022",
#         "system": "Linux",
#         "release": "5.15.0-1014-azure",
#         "libcver": [
#           "glibc",
#           "2.31"
#         ],
#         "n_cpus": 2,
#         "boot_time": "2022-08-01T09:59:44.000"
#       },
#       "python": {
#         "version_string": "3.8.13 (default, Jul 22 2022, 10:44:13) \n[GCC 9.4.0]",
#         "version": [
#           "3",
#           "8",
#           "13"
#         ],
#         "compiler": "GCC 9.4.0",
#         "implementation": "CPython",
#         "packages": [
#           {
#             "name": "Babel",
#             "version": "2.10.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Jinja2",
#             "version": "3.0.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "MarkupSafe",
#             "version": "2.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Pillow",
#             "version": "9.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "PyYAML",
#             "version": "6.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Pygments",
#             "version": "2.12.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "QtPy",
#             "version": "2.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Send2Trash",
#             "version": "1.8.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Sphinx",
#             "version": "3.5.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "alabaster",
#             "version": "0.7.12",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "argon2-cffi",
#             "version": "21.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "argon2-cffi-bindings",
#             "version": "21.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "astropy",
#             "version": "5.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "asttokens",
#             "version": "2.0.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "attrs",
#             "version": "22.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "backcall",
#             "version": "0.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "beautifulsoup4",
#             "version": "4.11.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "bleach",
#             "version": "5.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "bokeh",
#             "version": "2.4.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "certifi",
#             "version": "2022.6.15",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "cffi",
#             "version": "1.15.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "charset-normalizer",
#             "version": "2.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "corsikaio",
#             "version": "0.2.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ctapipe",
#             "version": "0.7.1.dev1230+g2c82d492",
#             "path": "/home/runner/work/ctapipe/ctapipe"
#           },
#           {
#             "name": "cycler",
#             "version": "0.11.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "debugpy",
#             "version": "1.6.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "decorator",
#             "version": "5.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "defusedxml",
#             "version": "0.7.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "docutils",
#             "version": "0.16",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "entrypoints",
#             "version": "0.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "eventio",
#             "version": "1.9.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "executing",
#             "version": "0.9.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "fastjsonschema",
#             "version": "2.16.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "fonttools",
#             "version": "4.34.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "graphviz",
#             "version": "0.20.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "h5py",
#             "version": "3.7.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "idna",
#             "version": "3.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "imagesize",
#             "version": "1.4.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "iminuit",
#             "version": "2.15.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "importlib-metadata",
#             "version": "4.12.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "importlib-resources",
#             "version": "5.9.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipykernel",
#             "version": "6.15.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipython",
#             "version": "8.4.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipython-genutils",
#             "version": "0.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipywidgets",
#             "version": "7.7.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jedi",
#             "version": "0.18.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "joblib",
#             "version": "1.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jsonschema",
#             "version": "4.9.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter",
#             "version": "1.0.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter-client",
#             "version": "7.3.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter-console",
#             "version": "6.4.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter-core",
#             "version": "4.11.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyterlab-pygments",
#             "version": "0.2.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyterlab-widgets",
#             "version": "1.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "kiwisolver",
#             "version": "1.4.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "llvmlite",
#             "version": "0.39.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "matplotlib",
#             "version": "3.5.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "matplotlib-inline",
#             "version": "0.1.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "mistune",
#             "version": "0.8.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbclient",
#             "version": "0.6.6",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbconvert",
#             "version": "6.5.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbformat",
#             "version": "5.4.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbsphinx",
#             "version": "0.8.9",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nest-asyncio",
#             "version": "1.5.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "notebook",
#             "version": "6.4.12",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numba",
#             "version": "0.56.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numexpr",
#             "version": "2.8.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numpy",
#             "version": "1.22.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numpydoc",
#             "version": "1.4.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "packaging",
#             "version": "21.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pandas",
#             "version": "1.4.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pandocfilters",
#             "version": "1.5.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "parso",
#             "version": "0.8.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pexpect",
#             "version": "4.8.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pickleshare",
#             "version": "0.7.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pip",
#             "version": "22.2.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pkgutil-resolve-name",
#             "version": "1.3.10",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "prometheus-client",
#             "version": "0.14.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "prompt-toolkit",
#             "version": "3.0.30",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "psutil",
#             "version": "5.9.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ptyprocess",
#             "version": "0.7.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pure-eval",
#             "version": "0.2.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pycparser",
#             "version": "2.21",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyerfa",
#             "version": "2.0.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyparsing",
#             "version": "3.0.9",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyrsistent",
#             "version": "0.18.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "python-dateutil",
#             "version": "2.8.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pytz",
#             "version": "2022.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyzmq",
#             "version": "23.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "qtconsole",
#             "version": "5.3.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "requests",
#             "version": "2.28.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "scikit-learn",
#             "version": "1.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "scipy",
#             "version": "1.9.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "setuptools",
#             "version": "63.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "setuptools-scm",
#             "version": "7.0.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "six",
#             "version": "1.16.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "snowballstemmer",
#             "version": "2.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "soupsieve",
#             "version": "2.3.2.post1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinx-automodapi",
#             "version": "0.14.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinx-rtd-theme",
#             "version": "1.0.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-applehelp",
#             "version": "1.0.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-devhelp",
#             "version": "1.0.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-htmlhelp",
#             "version": "2.0.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-jsmath",
#             "version": "1.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-qthelp",
#             "version": "1.0.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-serializinghtml",
#             "version": "1.1.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "stack-data",
#             "version": "0.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tables",
#             "version": "3.7.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "terminado",
#             "version": "0.15.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "threadpoolctl",
#             "version": "3.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tinycss2",
#             "version": "1.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tomli",
#             "version": "2.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tornado",
#             "version": "6.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tqdm",
#             "version": "4.64.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "traitlets",
#             "version": "5.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "typing-extensions",
#             "version": "4.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "urllib3",
#             "version": "1.26.11",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "wcwidth",
#             "version": "0.2.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "webencodings",
#             "version": "0.5.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "wheel",
#             "version": "0.37.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "widgetsnbextension",
#             "version": "3.6.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "zipp",
#             "version": "3.8.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "zstandard",
#             "version": "0.18.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           }
#         ]
#       },
#       "environment": {
#         "CONDA_DEFAULT_ENV": null,
#         "CONDA_PREFIX": null,
#         "CONDA_PYTHON_EXE": null,
#         "CONDA_EXE": null,
#         "CONDA_PROMPT_MODIFIER": null,
#         "CONDA_SHLVL": null,
#         "PATH": "/opt/hostedtoolcache/Python/3.8.13/x64/bin:/opt/hostedtoolcache/Python/3.8.13/x64:/home/linuxbrew/.linuxbrew/bin:/home/linuxbrew/.linuxbrew/sbin:/home/runner/.local/bin:/opt/pipx_bin:/home/runner/.cargo/bin:/home/runner/.config/composer/vendor/bin:/usr/local/.ghcup/bin:/home/runner/.dotnet/tools:/snap/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin",
#         "LD_LIBRARY_PATH": "/opt/hostedtoolcache/Python/3.8.13/x64/lib",
#         "DYLD_LIBRARY_PATH": null,
#         "USER": "runner",
#         "HOME": "/home/runner",
#         "SHELL": null
#       },
#       "arguments": [
#         "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages/ipykernel_launcher.py",
#         "-f",
#         "/tmp/tmpcg_ktt14.json",
#         "--HistoryManager.hist_file=:memory:"
#       ],
#       "start_time_utc": "2022-08-01T10:06:04.063"
#     },
#     "input": [
#       {
#         "url": "/home/runner/work/ctapipe/ctapipe/docs/examples/subinput.txt",
#         "role": null
#       },
#       {
#         "url": "/home/runner/work/ctapipe/ctapipe/docs/examples/anothersubinput.txt",
#         "role": null
#       }
#     ],
#     "output": [
#       {
#         "url": "/home/runner/work/ctapipe/ctapipe/docs/examples/suboutput.txt",
#         "role": null
#       }
#     ],
#     "status": "sub",
#     "duration_min": 0.00013333333333420683
#   },
#   {
#     "activity_name": "sub2",
#     "activity_uuid": "da3e673a-040e-4534-9716-e952e2eff610",
#     "start": {
#       "time_utc": "2022-08-01T10:06:04.152"
#     },
#     "stop": {
#       "time_utc": "2022-08-01T10:06:04.162"
#     },
#     "system": {
#       "ctapipe_version": "0.7.1.dev1230+g2c82d492",
#       "ctapipe_resources_version": "not installed",
#       "eventio_version": "1.9.1",
#       "ctapipe_svc_path": null,
#       "executable": "/opt/hostedtoolcache/Python/3.8.13/x64/bin/python",
#       "platform": {
#         "architecture_bits": "64bit",
#         "architecture_linkage": "ELF",
#         "machine": "x86_64",
#         "processor": "x86_64",
#         "node": "fv-az180-230",
#         "version": "#17~20.04.1-Ubuntu SMP Thu Jun 23 20:01:51 UTC 2022",
#         "system": "Linux",
#         "release": "5.15.0-1014-azure",
#         "libcver": [
#           "glibc",
#           "2.31"
#         ],
#         "n_cpus": 2,
#         "boot_time": "2022-08-01T09:59:44.000"
#       },
#       "python": {
#         "version_string": "3.8.13 (default, Jul 22 2022, 10:44:13) \n[GCC 9.4.0]",
#         "version": [
#           "3",
#           "8",
#           "13"
#         ],
#         "compiler": "GCC 9.4.0",
#         "implementation": "CPython",
#         "packages": [
#           {
#             "name": "Babel",
#             "version": "2.10.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Jinja2",
#             "version": "3.0.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "MarkupSafe",
#             "version": "2.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Pillow",
#             "version": "9.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "PyYAML",
#             "version": "6.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Pygments",
#             "version": "2.12.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "QtPy",
#             "version": "2.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Send2Trash",
#             "version": "1.8.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "Sphinx",
#             "version": "3.5.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "alabaster",
#             "version": "0.7.12",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "argon2-cffi",
#             "version": "21.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "argon2-cffi-bindings",
#             "version": "21.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "astropy",
#             "version": "5.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "asttokens",
#             "version": "2.0.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "attrs",
#             "version": "22.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "backcall",
#             "version": "0.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "beautifulsoup4",
#             "version": "4.11.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "bleach",
#             "version": "5.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "bokeh",
#             "version": "2.4.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "certifi",
#             "version": "2022.6.15",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "cffi",
#             "version": "1.15.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "charset-normalizer",
#             "version": "2.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "corsikaio",
#             "version": "0.2.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ctapipe",
#             "version": "0.7.1.dev1230+g2c82d492",
#             "path": "/home/runner/work/ctapipe/ctapipe"
#           },
#           {
#             "name": "cycler",
#             "version": "0.11.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "debugpy",
#             "version": "1.6.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "decorator",
#             "version": "5.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "defusedxml",
#             "version": "0.7.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "docutils",
#             "version": "0.16",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "entrypoints",
#             "version": "0.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "eventio",
#             "version": "1.9.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "executing",
#             "version": "0.9.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "fastjsonschema",
#             "version": "2.16.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "fonttools",
#             "version": "4.34.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "graphviz",
#             "version": "0.20.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "h5py",
#             "version": "3.7.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "idna",
#             "version": "3.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "imagesize",
#             "version": "1.4.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "iminuit",
#             "version": "2.15.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "importlib-metadata",
#             "version": "4.12.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "importlib-resources",
#             "version": "5.9.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipykernel",
#             "version": "6.15.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipython",
#             "version": "8.4.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipython-genutils",
#             "version": "0.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipywidgets",
#             "version": "7.7.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jedi",
#             "version": "0.18.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "joblib",
#             "version": "1.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jsonschema",
#             "version": "4.9.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter",
#             "version": "1.0.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter-client",
#             "version": "7.3.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter-console",
#             "version": "6.4.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter-core",
#             "version": "4.11.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyterlab-pygments",
#             "version": "0.2.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyterlab-widgets",
#             "version": "1.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "kiwisolver",
#             "version": "1.4.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "llvmlite",
#             "version": "0.39.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "matplotlib",
#             "version": "3.5.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "matplotlib-inline",
#             "version": "0.1.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "mistune",
#             "version": "0.8.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbclient",
#             "version": "0.6.6",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbconvert",
#             "version": "6.5.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbformat",
#             "version": "5.4.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbsphinx",
#             "version": "0.8.9",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nest-asyncio",
#             "version": "1.5.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "notebook",
#             "version": "6.4.12",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numba",
#             "version": "0.56.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numexpr",
#             "version": "2.8.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numpy",
#             "version": "1.22.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numpydoc",
#             "version": "1.4.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "packaging",
#             "version": "21.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pandas",
#             "version": "1.4.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pandocfilters",
#             "version": "1.5.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "parso",
#             "version": "0.8.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pexpect",
#             "version": "4.8.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pickleshare",
#             "version": "0.7.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pip",
#             "version": "22.2.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pkgutil-resolve-name",
#             "version": "1.3.10",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "prometheus-client",
#             "version": "0.14.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "prompt-toolkit",
#             "version": "3.0.30",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "psutil",
#             "version": "5.9.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ptyprocess",
#             "version": "0.7.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pure-eval",
#             "version": "0.2.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pycparser",
#             "version": "2.21",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyerfa",
#             "version": "2.0.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyparsing",
#             "version": "3.0.9",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyrsistent",
#             "version": "0.18.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "python-dateutil",
#             "version": "2.8.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pytz",
#             "version": "2022.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyzmq",
#             "version": "23.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "qtconsole",
#             "version": "5.3.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "requests",
#             "version": "2.28.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "scikit-learn",
#             "version": "1.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "scipy",
#             "version": "1.9.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "setuptools",
#             "version": "63.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "setuptools-scm",
#             "version": "7.0.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "six",
#             "version": "1.16.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "snowballstemmer",
#             "version": "2.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "soupsieve",
#             "version": "2.3.2.post1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinx-automodapi",
#             "version": "0.14.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinx-rtd-theme",
#             "version": "1.0.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-applehelp",
#             "version": "1.0.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-devhelp",
#             "version": "1.0.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-htmlhelp",
#             "version": "2.0.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-jsmath",
#             "version": "1.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-qthelp",
#             "version": "1.0.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-serializinghtml",
#             "version": "1.1.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "stack-data",
#             "version": "0.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tables",
#             "version": "3.7.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "terminado",
#             "version": "0.15.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "threadpoolctl",
#             "version": "3.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tinycss2",
#             "version": "1.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tomli",
#             "version": "2.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tornado",
#             "version": "6.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tqdm",
#             "version": "4.64.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "traitlets",
#             "version": "5.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "typing-extensions",
#             "version": "4.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "urllib3",
#             "version": "1.26.11",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "wcwidth",
#             "version": "0.2.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "webencodings",
#             "version": "0.5.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "wheel",
#             "version": "0.37.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "widgetsnbextension",
#             "version": "3.6.1",
# ...
#             "version": "8.4.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipython-genutils",
#             "version": "0.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ipywidgets",
#             "version": "7.7.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jedi",
#             "version": "0.18.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "joblib",
#             "version": "1.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jsonschema",
#             "version": "4.9.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter",
#             "version": "1.0.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter-client",
#             "version": "7.3.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter-console",
#             "version": "6.4.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyter-core",
#             "version": "4.11.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyterlab-pygments",
#             "version": "0.2.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "jupyterlab-widgets",
#             "version": "1.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "kiwisolver",
#             "version": "1.4.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "llvmlite",
#             "version": "0.39.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "matplotlib",
#             "version": "3.5.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "matplotlib-inline",
#             "version": "0.1.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "mistune",
#             "version": "0.8.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbclient",
#             "version": "0.6.6",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbconvert",
#             "version": "6.5.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbformat",
#             "version": "5.4.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nbsphinx",
#             "version": "0.8.9",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "nest-asyncio",
#             "version": "1.5.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "notebook",
#             "version": "6.4.12",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numba",
#             "version": "0.56.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numexpr",
#             "version": "2.8.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numpy",
#             "version": "1.22.4",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "numpydoc",
#             "version": "1.4.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "packaging",
#             "version": "21.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pandas",
#             "version": "1.4.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pandocfilters",
#             "version": "1.5.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "parso",
#             "version": "0.8.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pexpect",
#             "version": "4.8.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pickleshare",
#             "version": "0.7.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pip",
#             "version": "22.2.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pkgutil-resolve-name",
#             "version": "1.3.10",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "prometheus-client",
#             "version": "0.14.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "prompt-toolkit",
#             "version": "3.0.30",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "psutil",
#             "version": "5.9.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "ptyprocess",
#             "version": "0.7.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pure-eval",
#             "version": "0.2.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pycparser",
#             "version": "2.21",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyerfa",
#             "version": "2.0.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyparsing",
#             "version": "3.0.9",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyrsistent",
#             "version": "0.18.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "python-dateutil",
#             "version": "2.8.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pytz",
#             "version": "2022.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "pyzmq",
#             "version": "23.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "qtconsole",
#             "version": "5.3.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "requests",
#             "version": "2.28.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "scikit-learn",
#             "version": "1.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "scipy",
#             "version": "1.9.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "setuptools",
#             "version": "63.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "setuptools-scm",
#             "version": "7.0.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "six",
#             "version": "1.16.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "snowballstemmer",
#             "version": "2.2.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "soupsieve",
#             "version": "2.3.2.post1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinx-automodapi",
#             "version": "0.14.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinx-rtd-theme",
#             "version": "1.0.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-applehelp",
#             "version": "1.0.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-devhelp",
#             "version": "1.0.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-htmlhelp",
#             "version": "2.0.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-jsmath",
#             "version": "1.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-qthelp",
#             "version": "1.0.3",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "sphinxcontrib-serializinghtml",
#             "version": "1.1.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "stack-data",
#             "version": "0.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tables",
#             "version": "3.7.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "terminado",
#             "version": "0.15.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "threadpoolctl",
#             "version": "3.1.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tinycss2",
#             "version": "1.1.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tomli",
#             "version": "2.0.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tornado",
#             "version": "6.2",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "tqdm",
#             "version": "4.64.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "traitlets",
#             "version": "5.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "typing-extensions",
#             "version": "4.3.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "urllib3",
#             "version": "1.26.11",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "wcwidth",
#             "version": "0.2.5",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "webencodings",
#             "version": "0.5.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "wheel",
#             "version": "0.37.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "widgetsnbextension",
#             "version": "3.6.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "zipp",
#             "version": "3.8.1",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           },
#           {
#             "name": "zstandard",
#             "version": "0.18.0",
#             "path": "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages"
#           }
#         ]
#       },
#       "environment": {
#         "CONDA_DEFAULT_ENV": null,
#         "CONDA_PREFIX": null,
#         "CONDA_PYTHON_EXE": null,
#         "CONDA_EXE": null,
#         "CONDA_PROMPT_MODIFIER": null,
#         "CONDA_SHLVL": null,
#         "PATH": "/opt/hostedtoolcache/Python/3.8.13/x64/bin:/opt/hostedtoolcache/Python/3.8.13/x64:/home/linuxbrew/.linuxbrew/bin:/home/linuxbrew/.linuxbrew/sbin:/home/runner/.local/bin:/opt/pipx_bin:/home/runner/.cargo/bin:/home/runner/.config/composer/vendor/bin:/usr/local/.ghcup/bin:/home/runner/.dotnet/tools:/snap/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin",
#         "LD_LIBRARY_PATH": "/opt/hostedtoolcache/Python/3.8.13/x64/lib",
#         "DYLD_LIBRARY_PATH": null,
#         "USER": "runner",
#         "HOME": "/home/runner",
#         "SHELL": null
#       },
#       "arguments": [
#         "/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages/ipykernel_launcher.py",
#         "-f",
#         "/tmp/tmpcg_ktt14.json",
#         "--HistoryManager.hist_file=:memory:"
#       ],
#       "start_time_utc": "2022-08-01T10:06:04.055"
#     },
#     "input": [
#       {
#         "url": "/home/runner/work/ctapipe/ctapipe/docs/examples/test.txt",
#         "role": null
#       }
#     ],
#     "output": [],
#     "status": "completed",
#     "duration_min": 0.002166666666640893
#   }
# ]

# %% [markdown]
# ## Storing provenance info in output files
#
# * already this can be stored in something like an HDF5 file header, which allows hierarchies.
# * Try to flatted the data so it can be stored in a key=value header in a **FITS file** (using the FITS extended keyword convention to allow >8 character keywords), or as a table

# %%
def flatten_dict(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '.')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '.')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
d = dict(activity=p.provenance)

# %%
pprint(flatten_dict(d))
# Out:
# {'activity.0.activity_name': 'sub',
#  'activity.0.activity_uuid': '26cf18b1-81db-4820-b6ce-d7d02806ba5d',
#  'activity.0.duration_min': 0.00013333333333420683,
#  'activity.0.input.0.role': None,
#  'activity.0.input.0.url': '/home/runner/work/ctapipe/ctapipe/docs/examples/subinput.txt',
#  'activity.0.input.1.role': None,
#  'activity.0.input.1.url': '/home/runner/work/ctapipe/ctapipe/docs/examples/anothersubinput.txt',
#  'activity.0.output.0.role': None,
#  'activity.0.output.0.url': '/home/runner/work/ctapipe/ctapipe/docs/examples/suboutput.txt',
#  'activity.0.start.time_utc': '2022-08-01T10:06:04.055',
#  'activity.0.status': 'sub',
#  'activity.0.stop.time_utc': '2022-08-01T10:06:04.063',
#  'activity.0.system.arguments.0': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages/ipykernel_launcher.py',
#  'activity.0.system.arguments.1': '-f',
#  'activity.0.system.arguments.2': '/tmp/tmpcg_ktt14.json',
#  'activity.0.system.arguments.3': '--HistoryManager.hist_file=:memory:',
#  'activity.0.system.ctapipe_resources_version': 'not installed',
#  'activity.0.system.ctapipe_svc_path': None,
#  'activity.0.system.ctapipe_version': '0.7.1.dev1230+g2c82d492',
#  'activity.0.system.environment.CONDA_DEFAULT_ENV': None,
#  'activity.0.system.environment.CONDA_EXE': None,
#  'activity.0.system.environment.CONDA_PREFIX': None,
#  'activity.0.system.environment.CONDA_PROMPT_MODIFIER': None,
#  'activity.0.system.environment.CONDA_PYTHON_EXE': None,
#  'activity.0.system.environment.CONDA_SHLVL': None,
#  'activity.0.system.environment.DYLD_LIBRARY_PATH': None,
#  'activity.0.system.environment.HOME': '/home/runner',
#  'activity.0.system.environment.LD_LIBRARY_PATH': '/opt/hostedtoolcache/Python/3.8.13/x64/lib',
#  'activity.0.system.environment.PATH': '/opt/hostedtoolcache/Python/3.8.13/x64/bin:/opt/hostedtoolcache/Python/3.8.13/x64:/home/linuxbrew/.linuxbrew/bin:/home/linuxbrew/.linuxbrew/sbin:/home/runner/.local/bin:/opt/pipx_bin:/home/runner/.cargo/bin:/home/runner/.config/composer/vendor/bin:/usr/local/.ghcup/bin:/home/runner/.dotnet/tools:/snap/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin',
#  'activity.0.system.environment.SHELL': None,
#  'activity.0.system.environment.USER': 'runner',
#  'activity.0.system.eventio_version': '1.9.1',
#  'activity.0.system.executable': '/opt/hostedtoolcache/Python/3.8.13/x64/bin/python',
#  'activity.0.system.platform.architecture_bits': '64bit',
#  'activity.0.system.platform.architecture_linkage': 'ELF',
#  'activity.0.system.platform.boot_time': '2022-08-01T09:59:44.000',
#  'activity.0.system.platform.libcver': ('glibc', '2.31'),
#  'activity.0.system.platform.machine': 'x86_64',
#  'activity.0.system.platform.n_cpus': 2,
#  'activity.0.system.platform.node': 'fv-az180-230',
#  'activity.0.system.platform.processor': 'x86_64',
#  'activity.0.system.platform.release': '5.15.0-1014-azure',
#  'activity.0.system.platform.system': 'Linux',
#  'activity.0.system.platform.version': '#17~20.04.1-Ubuntu SMP Thu Jun 23 '
#                                        '20:01:51 UTC 2022',
#  'activity.0.system.python.compiler': 'GCC 9.4.0',
#  'activity.0.system.python.implementation': 'CPython',
#  'activity.0.system.python.packages.0.name': 'Babel',
#  'activity.0.system.python.packages.0.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.0.version': '2.10.3',
#  'activity.0.system.python.packages.1.name': 'Jinja2',
#  'activity.0.system.python.packages.1.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.1.version': '3.0.3',
#  'activity.0.system.python.packages.10.name': 'argon2-cffi',
#  'activity.0.system.python.packages.10.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.10.version': '21.3.0',
#  'activity.0.system.python.packages.100.name': 'sphinxcontrib-applehelp',
#  'activity.0.system.python.packages.100.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.100.version': '1.0.2',
#  'activity.0.system.python.packages.101.name': 'sphinxcontrib-devhelp',
#  'activity.0.system.python.packages.101.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.101.version': '1.0.2',
#  'activity.0.system.python.packages.102.name': 'sphinxcontrib-htmlhelp',
#  'activity.0.system.python.packages.102.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.102.version': '2.0.0',
#  'activity.0.system.python.packages.103.name': 'sphinxcontrib-jsmath',
#  'activity.0.system.python.packages.103.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.103.version': '1.0.1',
#  'activity.0.system.python.packages.104.name': 'sphinxcontrib-qthelp',
#  'activity.0.system.python.packages.104.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.104.version': '1.0.3',
#  'activity.0.system.python.packages.105.name': 'sphinxcontrib-serializinghtml',
#  'activity.0.system.python.packages.105.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.105.version': '1.1.5',
#  'activity.0.system.python.packages.106.name': 'stack-data',
#  'activity.0.system.python.packages.106.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.106.version': '0.3.0',
#  'activity.0.system.python.packages.107.name': 'tables',
#  'activity.0.system.python.packages.107.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.107.version': '3.7.0',
#  'activity.0.system.python.packages.108.name': 'terminado',
#  'activity.0.system.python.packages.108.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.108.version': '0.15.0',
#  'activity.0.system.python.packages.109.name': 'threadpoolctl',
#  'activity.0.system.python.packages.109.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.109.version': '3.1.0',
#  'activity.0.system.python.packages.11.name': 'argon2-cffi-bindings',
#  'activity.0.system.python.packages.11.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.11.version': '21.2.0',
#  'activity.0.system.python.packages.110.name': 'tinycss2',
#  'activity.0.system.python.packages.110.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.110.version': '1.1.1',
#  'activity.0.system.python.packages.111.name': 'tomli',
#  'activity.0.system.python.packages.111.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.111.version': '2.0.1',
#  'activity.0.system.python.packages.112.name': 'tornado',
#  'activity.0.system.python.packages.112.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.112.version': '6.2',
#  'activity.0.system.python.packages.113.name': 'tqdm',
#  'activity.0.system.python.packages.113.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.113.version': '4.64.0',
#  'activity.0.system.python.packages.114.name': 'traitlets',
#  'activity.0.system.python.packages.114.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.114.version': '5.3.0',
#  'activity.0.system.python.packages.115.name': 'typing-extensions',
#  'activity.0.system.python.packages.115.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.115.version': '4.3.0',
#  'activity.0.system.python.packages.116.name': 'urllib3',
#  'activity.0.system.python.packages.116.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.116.version': '1.26.11',
#  'activity.0.system.python.packages.117.name': 'wcwidth',
#  'activity.0.system.python.packages.117.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.117.version': '0.2.5',
#  'activity.0.system.python.packages.118.name': 'webencodings',
#  'activity.0.system.python.packages.118.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.118.version': '0.5.1',
#  'activity.0.system.python.packages.119.name': 'wheel',
#  'activity.0.system.python.packages.119.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.119.version': '0.37.1',
#  'activity.0.system.python.packages.12.name': 'astropy',
#  'activity.0.system.python.packages.12.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.12.version': '5.1',
#  'activity.0.system.python.packages.120.name': 'widgetsnbextension',
#  'activity.0.system.python.packages.120.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.120.version': '3.6.1',
#  'activity.0.system.python.packages.121.name': 'zipp',
#  'activity.0.system.python.packages.121.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.121.version': '3.8.1',
#  'activity.0.system.python.packages.122.name': 'zstandard',
#  'activity.0.system.python.packages.122.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.122.version': '0.18.0',
#  'activity.0.system.python.packages.13.name': 'asttokens',
#  'activity.0.system.python.packages.13.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.13.version': '2.0.5',
#  'activity.0.system.python.packages.14.name': 'attrs',
#  'activity.0.system.python.packages.14.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.14.version': '22.1.0',
#  'activity.0.system.python.packages.15.name': 'backcall',
#  'activity.0.system.python.packages.15.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.15.version': '0.2.0',
#  'activity.0.system.python.packages.16.name': 'beautifulsoup4',
#  'activity.0.system.python.packages.16.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.16.version': '4.11.1',
#  'activity.0.system.python.packages.17.name': 'bleach',
#  'activity.0.system.python.packages.17.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.17.version': '5.0.1',
#  'activity.0.system.python.packages.18.name': 'bokeh',
#  'activity.0.system.python.packages.18.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.18.version': '2.4.3',
#  'activity.0.system.python.packages.19.name': 'certifi',
#  'activity.0.system.python.packages.19.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.19.version': '2022.6.15',
#  'activity.0.system.python.packages.2.name': 'MarkupSafe',
#  'activity.0.system.python.packages.2.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.2.version': '2.1.1',
#  'activity.0.system.python.packages.20.name': 'cffi',
#  'activity.0.system.python.packages.20.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.20.version': '1.15.1',
#  'activity.0.system.python.packages.21.name': 'charset-normalizer',
#  'activity.0.system.python.packages.21.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.21.version': '2.1.0',
#  'activity.0.system.python.packages.22.name': 'corsikaio',
#  'activity.0.system.python.packages.22.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.22.version': '0.2.5',
#  'activity.0.system.python.packages.23.name': 'ctapipe',
#  'activity.0.system.python.packages.23.path': '/home/runner/work/ctapipe/ctapipe',
#  'activity.0.system.python.packages.23.version': '0.7.1.dev1230+g2c82d492',
#  'activity.0.system.python.packages.24.name': 'cycler',
#  'activity.0.system.python.packages.24.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.24.version': '0.11.0',
#  'activity.0.system.python.packages.25.name': 'debugpy',
#  'activity.0.system.python.packages.25.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.25.version': '1.6.2',
#  'activity.0.system.python.packages.26.name': 'decorator',
#  'activity.0.system.python.packages.26.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.26.version': '5.1.1',
#  'activity.0.system.python.packages.27.name': 'defusedxml',
#  'activity.0.system.python.packages.27.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.27.version': '0.7.1',
#  'activity.0.system.python.packages.28.name': 'docutils',
#  'activity.0.system.python.packages.28.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.28.version': '0.16',
#  'activity.0.system.python.packages.29.name': 'entrypoints',
#  'activity.0.system.python.packages.29.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.29.version': '0.4',
#  'activity.0.system.python.packages.3.name': 'Pillow',
#  'activity.0.system.python.packages.3.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.3.version': '9.2.0',
#  'activity.0.system.python.packages.30.name': 'eventio',
#  'activity.0.system.python.packages.30.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.30.version': '1.9.1',
#  'activity.0.system.python.packages.31.name': 'executing',
#  'activity.0.system.python.packages.31.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.31.version': '0.9.1',
#  'activity.0.system.python.packages.32.name': 'fastjsonschema',
#  'activity.0.system.python.packages.32.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.32.version': '2.16.1',
#  'activity.0.system.python.packages.33.name': 'fonttools',
#  'activity.0.system.python.packages.33.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.33.version': '4.34.4',
#  'activity.0.system.python.packages.34.name': 'graphviz',
#  'activity.0.system.python.packages.34.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.34.version': '0.20.1',
#  'activity.0.system.python.packages.35.name': 'h5py',
#  'activity.0.system.python.packages.35.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.35.version': '3.7.0',
#  'activity.0.system.python.packages.36.name': 'idna',
#  'activity.0.system.python.packages.36.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.36.version': '3.3',
#  'activity.0.system.python.packages.37.name': 'imagesize',
#  'activity.0.system.python.packages.37.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.37.version': '1.4.1',
#  'activity.0.system.python.packages.38.name': 'iminuit',
#  'activity.0.system.python.packages.38.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.38.version': '2.15.1',
#  'activity.0.system.python.packages.39.name': 'importlib-metadata',
#  'activity.0.system.python.packages.39.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.39.version': '4.12.0',
#  'activity.0.system.python.packages.4.name': 'PyYAML',
#  'activity.0.system.python.packages.4.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.4.version': '6.0',
#  'activity.0.system.python.packages.40.name': 'importlib-resources',
#  'activity.0.system.python.packages.40.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.40.version': '5.9.0',
#  'activity.0.system.python.packages.41.name': 'ipykernel',
#  'activity.0.system.python.packages.41.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.41.version': '6.15.1',
#  'activity.0.system.python.packages.42.name': 'ipython',
#  'activity.0.system.python.packages.42.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.42.version': '8.4.0',
#  'activity.0.system.python.packages.43.name': 'ipython-genutils',
#  'activity.0.system.python.packages.43.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.43.version': '0.2.0',
#  'activity.0.system.python.packages.44.name': 'ipywidgets',
#  'activity.0.system.python.packages.44.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.44.version': '7.7.1',
#  'activity.0.system.python.packages.45.name': 'jedi',
#  'activity.0.system.python.packages.45.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.45.version': '0.18.1',
#  'activity.0.system.python.packages.46.name': 'joblib',
#  'activity.0.system.python.packages.46.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.46.version': '1.1.0',
#  'activity.0.system.python.packages.47.name': 'jsonschema',
#  'activity.0.system.python.packages.47.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.47.version': '4.9.0',
#  'activity.0.system.python.packages.48.name': 'jupyter',
#  'activity.0.system.python.packages.48.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.48.version': '1.0.0',
#  'activity.0.system.python.packages.49.name': 'jupyter-client',
#  'activity.0.system.python.packages.49.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.49.version': '7.3.4',
#  'activity.0.system.python.packages.5.name': 'Pygments',
#  'activity.0.system.python.packages.5.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.5.version': '2.12.0',
#  'activity.0.system.python.packages.50.name': 'jupyter-console',
#  'activity.0.system.python.packages.50.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.50.version': '6.4.4',
#  'activity.0.system.python.packages.51.name': 'jupyter-core',
#  'activity.0.system.python.packages.51.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.51.version': '4.11.1',
#  'activity.0.system.python.packages.52.name': 'jupyterlab-pygments',
#  'activity.0.system.python.packages.52.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.52.version': '0.2.2',
#  'activity.0.system.python.packages.53.name': 'jupyterlab-widgets',
#  'activity.0.system.python.packages.53.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.53.version': '1.1.1',
#  'activity.0.system.python.packages.54.name': 'kiwisolver',
#  'activity.0.system.python.packages.54.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.54.version': '1.4.4',
#  'activity.0.system.python.packages.55.name': 'llvmlite',
#  'activity.0.system.python.packages.55.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.55.version': '0.39.0',
#  'activity.0.system.python.packages.56.name': 'matplotlib',
#  'activity.0.system.python.packages.56.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.56.version': '3.5.2',
#  'activity.0.system.python.packages.57.name': 'matplotlib-inline',
#  'activity.0.system.python.packages.57.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.57.version': '0.1.3',
#  'activity.0.system.python.packages.58.name': 'mistune',
#  'activity.0.system.python.packages.58.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.58.version': '0.8.4',
#  'activity.0.system.python.packages.59.name': 'nbclient',
#  'activity.0.system.python.packages.59.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.59.version': '0.6.6',
#  'activity.0.system.python.packages.6.name': 'QtPy',
#  'activity.0.system.python.packages.6.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.6.version': '2.1.0',
#  'activity.0.system.python.packages.60.name': 'nbconvert',
#  'activity.0.system.python.packages.60.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.60.version': '6.5.0',
#  'activity.0.system.python.packages.61.name': 'nbformat',
#  'activity.0.system.python.packages.61.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.61.version': '5.4.0',
#  'activity.0.system.python.packages.62.name': 'nbsphinx',
#  'activity.0.system.python.packages.62.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.62.version': '0.8.9',
#  'activity.0.system.python.packages.63.name': 'nest-asyncio',
#  'activity.0.system.python.packages.63.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.63.version': '1.5.5',
#  'activity.0.system.python.packages.64.name': 'notebook',
#  'activity.0.system.python.packages.64.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.64.version': '6.4.12',
#  'activity.0.system.python.packages.65.name': 'numba',
#  'activity.0.system.python.packages.65.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.65.version': '0.56.0',
#  'activity.0.system.python.packages.66.name': 'numexpr',
#  'activity.0.system.python.packages.66.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.66.version': '2.8.3',
#  'activity.0.system.python.packages.67.name': 'numpy',
#  'activity.0.system.python.packages.67.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.67.version': '1.22.4',
#  'activity.0.system.python.packages.68.name': 'numpydoc',
#  'activity.0.system.python.packages.68.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.68.version': '1.4.0',
#  'activity.0.system.python.packages.69.name': 'packaging',
#  'activity.0.system.python.packages.69.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.69.version': '21.3',
#  'activity.0.system.python.packages.7.name': 'Send2Trash',
#  'activity.0.system.python.packages.7.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.7.version': '1.8.0',
#  'activity.0.system.python.packages.70.name': 'pandas',
#  'activity.0.system.python.packages.70.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.70.version': '1.4.3',
#  'activity.0.system.python.packages.71.name': 'pandocfilters',
#  'activity.0.system.python.packages.71.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.71.version': '1.5.0',
#  'activity.0.system.python.packages.72.name': 'parso',
#  'activity.0.system.python.packages.72.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.72.version': '0.8.3',
#  'activity.0.system.python.packages.73.name': 'pexpect',
#  'activity.0.system.python.packages.73.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.73.version': '4.8.0',
#  'activity.0.system.python.packages.74.name': 'pickleshare',
#  'activity.0.system.python.packages.74.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.74.version': '0.7.5',
#  'activity.0.system.python.packages.75.name': 'pip',
#  'activity.0.system.python.packages.75.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.75.version': '22.2.1',
#  'activity.0.system.python.packages.76.name': 'pkgutil-resolve-name',
#  'activity.0.system.python.packages.76.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.76.version': '1.3.10',
#  'activity.0.system.python.packages.77.name': 'prometheus-client',
#  'activity.0.system.python.packages.77.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.77.version': '0.14.1',
#  'activity.0.system.python.packages.78.name': 'prompt-toolkit',
#  'activity.0.system.python.packages.78.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.78.version': '3.0.30',
#  'activity.0.system.python.packages.79.name': 'psutil',
#  'activity.0.system.python.packages.79.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.79.version': '5.9.1',
#  'activity.0.system.python.packages.8.name': 'Sphinx',
#  'activity.0.system.python.packages.8.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.8.version': '3.5.4',
#  'activity.0.system.python.packages.80.name': 'ptyprocess',
#  'activity.0.system.python.packages.80.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.80.version': '0.7.0',
#  'activity.0.system.python.packages.81.name': 'pure-eval',
#  'activity.0.system.python.packages.81.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.81.version': '0.2.2',
#  'activity.0.system.python.packages.82.name': 'pycparser',
#  'activity.0.system.python.packages.82.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.82.version': '2.21',
#  'activity.0.system.python.packages.83.name': 'pyerfa',
#  'activity.0.system.python.packages.83.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.83.version': '2.0.0.1',
#  'activity.0.system.python.packages.84.name': 'pyparsing',
#  'activity.0.system.python.packages.84.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.84.version': '3.0.9',
#  'activity.0.system.python.packages.85.name': 'pyrsistent',
#  'activity.0.system.python.packages.85.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.85.version': '0.18.1',
#  'activity.0.system.python.packages.86.name': 'python-dateutil',
#  'activity.0.system.python.packages.86.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.86.version': '2.8.2',
#  'activity.0.system.python.packages.87.name': 'pytz',
#  'activity.0.system.python.packages.87.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.87.version': '2022.1',
#  'activity.0.system.python.packages.88.name': 'pyzmq',
#  'activity.0.system.python.packages.88.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.88.version': '23.2.0',
#  'activity.0.system.python.packages.89.name': 'qtconsole',
#  'activity.0.system.python.packages.89.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.89.version': '5.3.1',
#  'activity.0.system.python.packages.9.name': 'alabaster',
#  'activity.0.system.python.packages.9.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.9.version': '0.7.12',
#  'activity.0.system.python.packages.90.name': 'requests',
#  'activity.0.system.python.packages.90.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.90.version': '2.28.1',
#  'activity.0.system.python.packages.91.name': 'scikit-learn',
#  'activity.0.system.python.packages.91.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.91.version': '1.1.1',
#  'activity.0.system.python.packages.92.name': 'scipy',
#  'activity.0.system.python.packages.92.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.92.version': '1.9.0',
#  'activity.0.system.python.packages.93.name': 'setuptools',
#  'activity.0.system.python.packages.93.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.93.version': '63.3.0',
#  'activity.0.system.python.packages.94.name': 'setuptools-scm',
#  'activity.0.system.python.packages.94.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.94.version': '7.0.5',
#  'activity.0.system.python.packages.95.name': 'six',
#  'activity.0.system.python.packages.95.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.95.version': '1.16.0',
#  'activity.0.system.python.packages.96.name': 'snowballstemmer',
#  'activity.0.system.python.packages.96.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.96.version': '2.2.0',
#  'activity.0.system.python.packages.97.name': 'soupsieve',
#  'activity.0.system.python.packages.97.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.97.version': '2.3.2.post1',
#  'activity.0.system.python.packages.98.name': 'sphinx-automodapi',
#  'activity.0.system.python.packages.98.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.98.version': '0.14.1',
#  'activity.0.system.python.packages.99.name': 'sphinx-rtd-theme',
#  'activity.0.system.python.packages.99.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.0.system.python.packages.99.version': '1.0.0',
#  'activity.0.system.python.version': ('3', '8', '13'),
#  'activity.0.system.python.version_string': '3.8.13 (default, Jul 22 2022, '
#                                             '10:44:13) \n'
#                                             '[GCC 9.4.0]',
#  'activity.0.system.start_time_utc': '2022-08-01T10:06:04.063',
#  'activity.1.activity_name': 'sub2',
#  'activity.1.activity_uuid': 'da3e673a-040e-4534-9716-e952e2eff610',
#  'activity.1.duration_min': 0.00016666666654785445,
#  'activity.1.input.0.role': None,
#  'activity.1.input.0.url': '/home/runner/work/ctapipe/ctapipe/docs/examples/sub2input.txt',
#  'activity.1.start.time_utc': '2022-08-01T10:06:04.152',
#  'activity.1.status': 'sub2',
#  'activity.1.stop.time_utc': '2022-08-01T10:06:04.162',
#  'activity.1.system.arguments.0': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages/ipykernel_launcher.py',
#  'activity.1.system.arguments.1': '-f',
#  'activity.1.system.arguments.2': '/tmp/tmpcg_ktt14.json',
#  'activity.1.system.arguments.3': '--HistoryManager.hist_file=:memory:',
#  'activity.1.system.ctapipe_resources_version': 'not installed',
#  'activity.1.system.ctapipe_svc_path': None,
#  'activity.1.system.ctapipe_version': '0.7.1.dev1230+g2c82d492',
#  'activity.1.system.environment.CONDA_DEFAULT_ENV': None,
#  'activity.1.system.environment.CONDA_EXE': None,
#  'activity.1.system.environment.CONDA_PREFIX': None,
#  'activity.1.system.environment.CONDA_PROMPT_MODIFIER': None,
#  'activity.1.system.environment.CONDA_PYTHON_EXE': None,
#  'activity.1.system.environment.CONDA_SHLVL': None,
#  'activity.1.system.environment.DYLD_LIBRARY_PATH': None,
#  'activity.1.system.environment.HOME': '/home/runner',
#  'activity.1.system.environment.LD_LIBRARY_PATH': '/opt/hostedtoolcache/Python/3.8.13/x64/lib',
#  'activity.1.system.environment.PATH': '/opt/hostedtoolcache/Python/3.8.13/x64/bin:/opt/hostedtoolcache/Python/3.8.13/x64:/home/linuxbrew/.linuxbrew/bin:/home/linuxbrew/.linuxbrew/sbin:/home/runner/.local/bin:/opt/pipx_bin:/home/runner/.cargo/bin:/home/runner/.config/composer/vendor/bin:/usr/local/.ghcup/bin:/home/runner/.dotnet/tools:/snap/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin',
#  'activity.1.system.environment.SHELL': None,
#  'activity.1.system.environment.USER': 'runner',
#  'activity.1.system.eventio_version': '1.9.1',
#  'activity.1.system.executable': '/opt/hostedtoolcache/Python/3.8.13/x64/bin/python',
#  'activity.1.system.platform.architecture_bits': '64bit',
#  'activity.1.system.platform.architecture_linkage': 'ELF',
#  'activity.1.system.platform.boot_time': '2022-08-01T09:59:44.000',
#  'activity.1.system.platform.libcver': ('glibc', '2.31'),
#  'activity.1.system.platform.machine': 'x86_64',
#  'activity.1.system.platform.n_cpus': 2,
#  'activity.1.system.platform.node': 'fv-az180-230',
#  'activity.1.system.platform.processor': 'x86_64',
#  'activity.1.system.platform.release': '5.15.0-1014-azure',
#  'activity.1.system.platform.system': 'Linux',
#  'activity.1.system.platform.version': '#17~20.04.1-Ubuntu SMP Thu Jun 23 '
#                                        '20:01:51 UTC 2022',
#  'activity.1.system.python.compiler': 'GCC 9.4.0',
#  'activity.1.system.python.implementation': 'CPython',
#  'activity.1.system.python.packages.0.name': 'Babel',
#  'activity.1.system.python.packages.0.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.0.version': '2.10.3',
#  'activity.1.system.python.packages.1.name': 'Jinja2',
#  'activity.1.system.python.packages.1.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.1.version': '3.0.3',
#  'activity.1.system.python.packages.10.name': 'argon2-cffi',
#  'activity.1.system.python.packages.10.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.10.version': '21.3.0',
#  'activity.1.system.python.packages.100.name': 'sphinxcontrib-applehelp',
#  'activity.1.system.python.packages.100.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.100.version': '1.0.2',
#  'activity.1.system.python.packages.101.name': 'sphinxcontrib-devhelp',
#  'activity.1.system.python.packages.101.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.101.version': '1.0.2',
#  'activity.1.system.python.packages.102.name': 'sphinxcontrib-htmlhelp',
#  'activity.1.system.python.packages.102.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.102.version': '2.0.0',
#  'activity.1.system.python.packages.103.name': 'sphinxcontrib-jsmath',
#  'activity.1.system.python.packages.103.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.103.version': '1.0.1',
#  'activity.1.system.python.packages.104.name': 'sphinxcontrib-qthelp',
#  'activity.1.system.python.packages.104.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.104.version': '1.0.3',
#  'activity.1.system.python.packages.105.name': 'sphinxcontrib-serializinghtml',
#  'activity.1.system.python.packages.105.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.105.version': '1.1.5',
#  'activity.1.system.python.packages.106.name': 'stack-data',
#  'activity.1.system.python.packages.106.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.106.version': '0.3.0',
#  'activity.1.system.python.packages.107.name': 'tables',
#  'activity.1.system.python.packages.107.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.107.version': '3.7.0',
#  'activity.1.system.python.packages.108.name': 'terminado',
#  'activity.1.system.python.packages.108.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.108.version': '0.15.0',
#  'activity.1.system.python.packages.109.name': 'threadpoolctl',
#  'activity.1.system.python.packages.109.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.109.version': '3.1.0',
#  'activity.1.system.python.packages.11.name': 'argon2-cffi-bindings',
#  'activity.1.system.python.packages.11.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.11.version': '21.2.0',
#  'activity.1.system.python.packages.110.name': 'tinycss2',
#  'activity.1.system.python.packages.110.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.110.version': '1.1.1',
#  'activity.1.system.python.packages.111.name': 'tomli',
#  'activity.1.system.python.packages.111.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.111.version': '2.0.1',
#  'activity.1.system.python.packages.112.name': 'tornado',
#  'activity.1.system.python.packages.112.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.112.version': '6.2',
#  'activity.1.system.python.packages.113.name': 'tqdm',
#  'activity.1.system.python.packages.113.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.113.version': '4.64.0',
#  'activity.1.system.python.packages.114.name': 'traitlets',
#  'activity.1.system.python.packages.114.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.114.version': '5.3.0',
#  'activity.1.system.python.packages.115.name': 'typing-extensions',
#  'activity.1.system.python.packages.115.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.115.version': '4.3.0',
#  'activity.1.system.python.packages.116.name': 'urllib3',
#  'activity.1.system.python.packages.116.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.116.version': '1.26.11',
#  'activity.1.system.python.packages.117.name': 'wcwidth',
#  'activity.1.system.python.packages.117.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.117.version': '0.2.5',
#  'activity.1.system.python.packages.118.name': 'webencodings',
#  'activity.1.system.python.packages.118.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.118.version': '0.5.1',
#  'activity.1.system.python.packages.119.name': 'wheel',
#  'activity.1.system.python.packages.119.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.119.version': '0.37.1',
#  'activity.1.system.python.packages.12.name': 'astropy',
#  'activity.1.system.python.packages.12.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.12.version': '5.1',
#  'activity.1.system.python.packages.120.name': 'widgetsnbextension',
#  'activity.1.system.python.packages.120.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.120.version': '3.6.1',
#  'activity.1.system.python.packages.121.name': 'zipp',
#  'activity.1.system.python.packages.121.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.121.version': '3.8.1',
#  'activity.1.system.python.packages.122.name': 'zstandard',
#  'activity.1.system.python.packages.122.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.122.version': '0.18.0',
#  'activity.1.system.python.packages.13.name': 'asttokens',
#  'activity.1.system.python.packages.13.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.13.version': '2.0.5',
#  'activity.1.system.python.packages.14.name': 'attrs',
#  'activity.1.system.python.packages.14.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.14.version': '22.1.0',
#  'activity.1.system.python.packages.15.name': 'backcall',
#  'activity.1.system.python.packages.15.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.15.version': '0.2.0',
#  'activity.1.system.python.packages.16.name': 'beautifulsoup4',
#  'activity.1.system.python.packages.16.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.16.version': '4.11.1',
#  'activity.1.system.python.packages.17.name': 'bleach',
#  'activity.1.system.python.packages.17.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.17.version': '5.0.1',
#  'activity.1.system.python.packages.18.name': 'bokeh',
#  'activity.1.system.python.packages.18.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.18.version': '2.4.3',
#  'activity.1.system.python.packages.19.name': 'certifi',
#  'activity.1.system.python.packages.19.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.19.version': '2022.6.15',
#  'activity.1.system.python.packages.2.name': 'MarkupSafe',
#  'activity.1.system.python.packages.2.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.2.version': '2.1.1',
#  'activity.1.system.python.packages.20.name': 'cffi',
#  'activity.1.system.python.packages.20.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.20.version': '1.15.1',
#  'activity.1.system.python.packages.21.name': 'charset-normalizer',
#  'activity.1.system.python.packages.21.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.21.version': '2.1.0',
#  'activity.1.system.python.packages.22.name': 'corsikaio',
#  'activity.1.system.python.packages.22.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.22.version': '0.2.5',
#  'activity.1.system.python.packages.23.name': 'ctapipe',
#  'activity.1.system.python.packages.23.path': '/home/runner/work/ctapipe/ctapipe',
#  'activity.1.system.python.packages.23.version': '0.7.1.dev1230+g2c82d492',
#  'activity.1.system.python.packages.24.name': 'cycler',
#  'activity.1.system.python.packages.24.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.24.version': '0.11.0',
#  'activity.1.system.python.packages.25.name': 'debugpy',
#  'activity.1.system.python.packages.25.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.25.version': '1.6.2',
#  'activity.1.system.python.packages.26.name': 'decorator',
#  'activity.1.system.python.packages.26.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.26.version': '5.1.1',
#  'activity.1.system.python.packages.27.name': 'defusedxml',
#  'activity.1.system.python.packages.27.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.27.version': '0.7.1',
#  'activity.1.system.python.packages.28.name': 'docutils',
#  'activity.1.system.python.packages.28.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.28.version': '0.16',
#  'activity.1.system.python.packages.29.name': 'entrypoints',
#  'activity.1.system.python.packages.29.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.29.version': '0.4',
#  'activity.1.system.python.packages.3.name': 'Pillow',
#  'activity.1.system.python.packages.3.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.3.version': '9.2.0',
#  'activity.1.system.python.packages.30.name': 'eventio',
#  'activity.1.system.python.packages.30.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.30.version': '1.9.1',
#  'activity.1.system.python.packages.31.name': 'executing',
#  'activity.1.system.python.packages.31.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.31.version': '0.9.1',
#  'activity.1.system.python.packages.32.name': 'fastjsonschema',
#  'activity.1.system.python.packages.32.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.32.version': '2.16.1',
#  'activity.1.system.python.packages.33.name': 'fonttools',
#  'activity.1.system.python.packages.33.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.33.version': '4.34.4',
#  'activity.1.system.python.packages.34.name': 'graphviz',
#  'activity.1.system.python.packages.34.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.34.version': '0.20.1',
#  'activity.1.system.python.packages.35.name': 'h5py',
#  'activity.1.system.python.packages.35.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.35.version': '3.7.0',
#  'activity.1.system.python.packages.36.name': 'idna',
#  'activity.1.system.python.packages.36.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.1.system.python.packages.36.version': '3.3',
#  'activity.1.system.python.packages.37.name': 'imagesize',
# ...
#  'activity.2.system.python.packages.39.name': 'importlib-metadata',
#  'activity.2.system.python.packages.39.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.39.version': '4.12.0',
#  'activity.2.system.python.packages.4.name': 'PyYAML',
#  'activity.2.system.python.packages.4.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.4.version': '6.0',
#  'activity.2.system.python.packages.40.name': 'importlib-resources',
#  'activity.2.system.python.packages.40.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.40.version': '5.9.0',
#  'activity.2.system.python.packages.41.name': 'ipykernel',
#  'activity.2.system.python.packages.41.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.41.version': '6.15.1',
#  'activity.2.system.python.packages.42.name': 'ipython',
#  'activity.2.system.python.packages.42.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.42.version': '8.4.0',
#  'activity.2.system.python.packages.43.name': 'ipython-genutils',
#  'activity.2.system.python.packages.43.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.43.version': '0.2.0',
#  'activity.2.system.python.packages.44.name': 'ipywidgets',
#  'activity.2.system.python.packages.44.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.44.version': '7.7.1',
#  'activity.2.system.python.packages.45.name': 'jedi',
#  'activity.2.system.python.packages.45.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.45.version': '0.18.1',
#  'activity.2.system.python.packages.46.name': 'joblib',
#  'activity.2.system.python.packages.46.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.46.version': '1.1.0',
#  'activity.2.system.python.packages.47.name': 'jsonschema',
#  'activity.2.system.python.packages.47.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.47.version': '4.9.0',
#  'activity.2.system.python.packages.48.name': 'jupyter',
#  'activity.2.system.python.packages.48.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.48.version': '1.0.0',
#  'activity.2.system.python.packages.49.name': 'jupyter-client',
#  'activity.2.system.python.packages.49.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.49.version': '7.3.4',
#  'activity.2.system.python.packages.5.name': 'Pygments',
#  'activity.2.system.python.packages.5.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.5.version': '2.12.0',
#  'activity.2.system.python.packages.50.name': 'jupyter-console',
#  'activity.2.system.python.packages.50.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.50.version': '6.4.4',
#  'activity.2.system.python.packages.51.name': 'jupyter-core',
#  'activity.2.system.python.packages.51.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.51.version': '4.11.1',
#  'activity.2.system.python.packages.52.name': 'jupyterlab-pygments',
#  'activity.2.system.python.packages.52.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.52.version': '0.2.2',
#  'activity.2.system.python.packages.53.name': 'jupyterlab-widgets',
#  'activity.2.system.python.packages.53.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.53.version': '1.1.1',
#  'activity.2.system.python.packages.54.name': 'kiwisolver',
#  'activity.2.system.python.packages.54.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.54.version': '1.4.4',
#  'activity.2.system.python.packages.55.name': 'llvmlite',
#  'activity.2.system.python.packages.55.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.55.version': '0.39.0',
#  'activity.2.system.python.packages.56.name': 'matplotlib',
#  'activity.2.system.python.packages.56.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.56.version': '3.5.2',
#  'activity.2.system.python.packages.57.name': 'matplotlib-inline',
#  'activity.2.system.python.packages.57.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.57.version': '0.1.3',
#  'activity.2.system.python.packages.58.name': 'mistune',
#  'activity.2.system.python.packages.58.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.58.version': '0.8.4',
#  'activity.2.system.python.packages.59.name': 'nbclient',
#  'activity.2.system.python.packages.59.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.59.version': '0.6.6',
#  'activity.2.system.python.packages.6.name': 'QtPy',
#  'activity.2.system.python.packages.6.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.6.version': '2.1.0',
#  'activity.2.system.python.packages.60.name': 'nbconvert',
#  'activity.2.system.python.packages.60.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.60.version': '6.5.0',
#  'activity.2.system.python.packages.61.name': 'nbformat',
#  'activity.2.system.python.packages.61.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.61.version': '5.4.0',
#  'activity.2.system.python.packages.62.name': 'nbsphinx',
#  'activity.2.system.python.packages.62.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.62.version': '0.8.9',
#  'activity.2.system.python.packages.63.name': 'nest-asyncio',
#  'activity.2.system.python.packages.63.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.63.version': '1.5.5',
#  'activity.2.system.python.packages.64.name': 'notebook',
#  'activity.2.system.python.packages.64.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.64.version': '6.4.12',
#  'activity.2.system.python.packages.65.name': 'numba',
#  'activity.2.system.python.packages.65.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.65.version': '0.56.0',
#  'activity.2.system.python.packages.66.name': 'numexpr',
#  'activity.2.system.python.packages.66.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.66.version': '2.8.3',
#  'activity.2.system.python.packages.67.name': 'numpy',
#  'activity.2.system.python.packages.67.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.67.version': '1.22.4',
#  'activity.2.system.python.packages.68.name': 'numpydoc',
#  'activity.2.system.python.packages.68.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.68.version': '1.4.0',
#  'activity.2.system.python.packages.69.name': 'packaging',
#  'activity.2.system.python.packages.69.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.69.version': '21.3',
#  'activity.2.system.python.packages.7.name': 'Send2Trash',
#  'activity.2.system.python.packages.7.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.7.version': '1.8.0',
#  'activity.2.system.python.packages.70.name': 'pandas',
#  'activity.2.system.python.packages.70.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.70.version': '1.4.3',
#  'activity.2.system.python.packages.71.name': 'pandocfilters',
#  'activity.2.system.python.packages.71.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.71.version': '1.5.0',
#  'activity.2.system.python.packages.72.name': 'parso',
#  'activity.2.system.python.packages.72.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.72.version': '0.8.3',
#  'activity.2.system.python.packages.73.name': 'pexpect',
#  'activity.2.system.python.packages.73.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.73.version': '4.8.0',
#  'activity.2.system.python.packages.74.name': 'pickleshare',
#  'activity.2.system.python.packages.74.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.74.version': '0.7.5',
#  'activity.2.system.python.packages.75.name': 'pip',
#  'activity.2.system.python.packages.75.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.75.version': '22.2.1',
#  'activity.2.system.python.packages.76.name': 'pkgutil-resolve-name',
#  'activity.2.system.python.packages.76.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.76.version': '1.3.10',
#  'activity.2.system.python.packages.77.name': 'prometheus-client',
#  'activity.2.system.python.packages.77.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.77.version': '0.14.1',
#  'activity.2.system.python.packages.78.name': 'prompt-toolkit',
#  'activity.2.system.python.packages.78.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.78.version': '3.0.30',
#  'activity.2.system.python.packages.79.name': 'psutil',
#  'activity.2.system.python.packages.79.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.79.version': '5.9.1',
#  'activity.2.system.python.packages.8.name': 'Sphinx',
#  'activity.2.system.python.packages.8.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.8.version': '3.5.4',
#  'activity.2.system.python.packages.80.name': 'ptyprocess',
#  'activity.2.system.python.packages.80.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.80.version': '0.7.0',
#  'activity.2.system.python.packages.81.name': 'pure-eval',
#  'activity.2.system.python.packages.81.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.81.version': '0.2.2',
#  'activity.2.system.python.packages.82.name': 'pycparser',
#  'activity.2.system.python.packages.82.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.82.version': '2.21',
#  'activity.2.system.python.packages.83.name': 'pyerfa',
#  'activity.2.system.python.packages.83.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.83.version': '2.0.0.1',
#  'activity.2.system.python.packages.84.name': 'pyparsing',
#  'activity.2.system.python.packages.84.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.84.version': '3.0.9',
#  'activity.2.system.python.packages.85.name': 'pyrsistent',
#  'activity.2.system.python.packages.85.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.85.version': '0.18.1',
#  'activity.2.system.python.packages.86.name': 'python-dateutil',
#  'activity.2.system.python.packages.86.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.86.version': '2.8.2',
#  'activity.2.system.python.packages.87.name': 'pytz',
#  'activity.2.system.python.packages.87.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.87.version': '2022.1',
#  'activity.2.system.python.packages.88.name': 'pyzmq',
#  'activity.2.system.python.packages.88.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.88.version': '23.2.0',
#  'activity.2.system.python.packages.89.name': 'qtconsole',
#  'activity.2.system.python.packages.89.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.89.version': '5.3.1',
#  'activity.2.system.python.packages.9.name': 'alabaster',
#  'activity.2.system.python.packages.9.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.9.version': '0.7.12',
#  'activity.2.system.python.packages.90.name': 'requests',
#  'activity.2.system.python.packages.90.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.90.version': '2.28.1',
#  'activity.2.system.python.packages.91.name': 'scikit-learn',
#  'activity.2.system.python.packages.91.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.91.version': '1.1.1',
#  'activity.2.system.python.packages.92.name': 'scipy',
#  'activity.2.system.python.packages.92.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.92.version': '1.9.0',
#  'activity.2.system.python.packages.93.name': 'setuptools',
#  'activity.2.system.python.packages.93.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.93.version': '63.3.0',
#  'activity.2.system.python.packages.94.name': 'setuptools-scm',
#  'activity.2.system.python.packages.94.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.94.version': '7.0.5',
#  'activity.2.system.python.packages.95.name': 'six',
#  'activity.2.system.python.packages.95.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.95.version': '1.16.0',
#  'activity.2.system.python.packages.96.name': 'snowballstemmer',
#  'activity.2.system.python.packages.96.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.96.version': '2.2.0',
#  'activity.2.system.python.packages.97.name': 'soupsieve',
#  'activity.2.system.python.packages.97.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.97.version': '2.3.2.post1',
#  'activity.2.system.python.packages.98.name': 'sphinx-automodapi',
#  'activity.2.system.python.packages.98.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.98.version': '0.14.1',
#  'activity.2.system.python.packages.99.name': 'sphinx-rtd-theme',
#  'activity.2.system.python.packages.99.path': '/opt/hostedtoolcache/Python/3.8.13/x64/lib/python3.8/site-packages',
#  'activity.2.system.python.packages.99.version': '1.0.0',
#  'activity.2.system.python.version': ('3', '8', '13'),
#  'activity.2.system.python.version_string': '3.8.13 (default, Jul 22 2022, '
#                                             '10:44:13) \n'
#                                             '[GCC 9.4.0]',
#  'activity.2.system.start_time_utc': '2022-08-01T10:06:04.055'}
